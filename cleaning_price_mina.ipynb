# %%
import pandas as pd

# %%
df=pd.read_csv("db/price.csv")

# %%
df.head()
# Out:
#    City Code          City      Lat      Lon         Metro        County  \
# 0       6181      New York  32.1679 -95.6691      New York        Queens
# 1      12447   Los Angeles  28.4658 -99.0000   Los Angeles   Los Angeles
# 2      17426       Chicago  41.8373 -87.6861       Chicago          Cook
# 3      39051       Houston  38.9177 -75.5041       Houston        Harris
# 4      13271  Philadelphia  35.6788 -84.3999  Philadelphia  Philadelphia
#
#   State  Population Rank  Nov-10  Dec-10   ...    Apr-16  May-16  Jun-16  \
# 0    NY                1     NaN     NaN   ...      2334    2339    2345
# 1    CA                2  2184.0  2184.0   ...      2637    2662    2687
# 2    IL                3  1563.0  1555.0   ...      1684    1686    1687
# 3    TX                4  1198.0  1199.0   ...      1444    1446    1446
# 4    PA                5  1092.0  1099.0   ...      1206    1211    1218
#
#    Jul-16  Aug-16  Sep-16  Oct-16  Nov-16  Dec-16  Jan-17
# ...

# %%
df2=df.set_index(["City Code","City","Lat","Lon","Metro","County","State","Population Rank"])
df2.head()
# Out:
#                                                                                          Nov-10  \
# City Code City         Lat     Lon      Metro        County       State Population Rank
# 6181      New York     32.1679 -95.6691 New York     Queens       NY    1                   NaN
# 12447     Los Angeles  28.4658 -99.0000 Los Angeles  Los Angeles  CA    2                2184.0
# 17426     Chicago      41.8373 -87.6861 Chicago      Cook         IL    3                1563.0
# 39051     Houston      38.9177 -75.5041 Houston      Harris       TX    4                1198.0
# 13271     Philadelphia 35.6788 -84.3999 Philadelphia Philadelphia PA    5                1092.0
#
#                                                                                          Dec-10  \
# City Code City         Lat     Lon      Metro        County       State Population Rank
# 6181      New York     32.1679 -95.6691 New York     Queens       NY    1                   NaN
# ...

# %%
df3=df2.stack().reset_index().rename(columns={"level_8":"m-y",0:"price"})
print(len(df3))
print(df3.head())
# Out:
# 960571
#    City Code      City      Lat      Lon     Metro  County State  \
# 0       6181  New York  32.1679 -95.6691  New York  Queens    NY
# 1       6181  New York  32.1679 -95.6691  New York  Queens    NY
# 2       6181  New York  32.1679 -95.6691  New York  Queens    NY
# 3       6181  New York  32.1679 -95.6691  New York  Queens    NY
# 4       6181  New York  32.1679 -95.6691  New York  Queens    NY
#
#    Population Rank     m-y   price
# 0                1  Dec-11  1746.0
# 1                1  Jan-12  1752.0
# 2                1  Feb-12  1764.0
# 3                1  Mar-12  1778.0
# 4                1  Apr-12  1792.0

# %%
months=[]
years=[]
for row in df3["m-y"]:
    months.append(row[:3])
    years.append(row[4:])
    
df3["month"]=months
df3["year"]=years
df3=df3.drop(["m-y"],axis=1)

# %%
test=df3.to_json()

# %%
test2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9085cf2db918> in <module>
# ----> 1 df3.value_counts()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'
